# %% [markdown]
# # Summer 2021 -> INSY 5379 -> Capstone Project
# ### UTA MSBA students:
# - Phanikrishna Karanam
# - Swetha Gollamudi
# - Joel Andrews
#
# #### Generic Web Scraper - Brand Promise
#
# __Summary__: This is a generic web scraper to extract details related to Brand Promise (based on claim) offered by Health IT vendors
#
# __Below steps are peformed__:
# - Read input file containing the URLs of HIT vendors
# - Open the URL in browser and extract the page source using Selenium
# - Parse the source html data using BeautifulSoup and extract required data
# - Filter & Preprocess the data
#   - Identify Stop words
# - Write extracted data into respective columns of output file based on identified keywords & modifiers
#    - Write errors into an error file
# - Extract all the href tags and filter thru the href_stop words
# - Repeat the above listed steps (from step 2 thru 5) for the urls obtained from the href tags
#
# __Next steps__:
# - By interacting with Canton domain experts:
#     - Identify Predictors / Regressors based on extracted text data
#     - Obtain / Create Training data and identify Target labels
# - Using extracted text data and build term matrix based on keywords & modifiers that appear on the output file
# - Use unsupervised learning methods for clustering the data and assign the cluster number as label
# - Using the output from unsupervised learning, train & build a Machine Learning models to classify labels in the target variable

# %%
import time 
from datetime import datetime

start_time = time.time()
start = datetime.now().strftime('%H:%M:%S')

print('Program Start Time:', start)
# Out:
# Program Start Time: 23:27:43

# %%
# Import necessary libraries

import pandas as pd
import bs4
from bs4 import BeautifulSoup as soup
from selenium import webdriver
import time
import re
import string
from urllib.parse import urljoin

# %%
def download_browser(my_url):
    executable_path = r'C:\Users\karan\AppData\Roaming\Python\Python37\site-packages\geckodriver.exe'
    
    options = webdriver.FirefoxOptions()
    
    # Selenium accesses the Chrome browser driver in incognito mode and without actually opening a browser window 
    # (headless argument). Any certificates errors are ignored
    options.add_argument('--ignore-certificate-errors')
    options.add_argument('--incognito')
    options.add_argument('--headless')
    
    browser = webdriver.Firefox(executable_path = executable_path, options = options)
    browser.get(my_url)
    
    # Pass the page source to Beautiful Soup for parsing
    page_soup = soup(browser.page_source, 'lxml')
    return (browser, page_soup)

# %%
in_file = 'C:/MSBA/Summer 2021/INSY 5379 - Capstone Project/HIT Vendors.xlsx'
keyword_file = 'C:/MSBA/Summer 2021/INSY 5379 - Capstone Project/brand_promise_high_level_keywords - Updated.xlsx'
out_file = 'C:/MSBA/Summer 2021/INSY 5379 - Capstone Project/HIT Output - Brand Promise.csv'
out_file_err = 'C:/MSBA/Summer 2021/INSY 5379 - Capstone Project/HIT Output_Error.csv'

header = ['Company Name', 'Claim', 'Modifier', 'Evidence', 'Link']
header_err = ['Company Name', 'Link', 'Error']

df = pd.read_excel(in_file)
df.drop_duplicates(subset = ['Name'], inplace = True)

input_list = df[['Name', 'Website']].values.tolist()

df_key = pd.read_excel(keyword_file).fillna('')
header_key = list(df_key.columns)

temp_list = df_key.values.tolist()
keywords_list = [list(filter(None, key_list)) for key_list in temp_list]

# %%
def write_file(keyword, modifier, txt, link):    
    temp = []
    temp = [comp_name, keyword, modifier, txt, link]   
    out.append(temp)
    return ()

# %%
def write_error_file(link):
    temp_err = []
    temp_err = [comp_name, link, e] 
    out_err.append(temp_err)
    return ()

# %%
stop_strings = ['@', '\.com', 'www\.', '__', '{', '}', '\.\.', '\[#', '\.js', '=', '\.css', '\.png']

href_stop_strings = ['support', 'video', 'podcast', 'case-study', 'contact', 'careers', 'disclaimer', 'terms', 'blog',
                     '\#top', 'privacy', 'policy', 'news', 'press', 'release', 'testimonial', 'signup', 'feed', 'webinar',
                     '\.css', '\.png', 'woff', 'manifest', 'cache', '\.ttf', '\.otf', '\.ico', '\.zip', '\.mp3', '\.xls',
                     '\.xml']

# %%
def extract_text(link): 
    browser, page_soup = download_browser(link)                             # Download browser and parse page source 

    # Sleep for 2 seconds for the page to respond
    time.sleep(2)                                                           # Sleep for 2 seconds for page to respond

    for text_string in page_soup.stripped_strings:   
        # Eliminate all non printable characters in text
        txt = re.sub('[^{}]'.format(string.printable), '', text_string.strip())

        # Eliminate multiple spaces in text
        txt_list = txt.split()                              
        txt = (' ').join(txt_list)

        if len(txt) > 2:
            skip_text = False

            for stop_string in stop_strings:                                # Eliminate all stop strings
                if re.search(stop_string.lower(), txt.lower()):
                    skip_text = True
                    break     

            # Skip if phone numbers are present and include those strings with less than 10 words
            if skip_text == False and len(re.sub('[^0-9]', '', txt)) <= 9 and len(txt_list) > 4:
                
                for keywords in keywords_list:     
                    if re.search(keywords[0].lower(), txt.lower()):                    
                    
                        for modifier in keywords[1:]:    
                            if re.search(modifier.lower(), txt.lower()):
                                
                                write_file(keywords[0].lower(), modifier, txt, link) # Capture all extracted & filtered text
                                #break                                         # If required to stop after 1st modifier hit
        
    return (browser, page_soup)

# %%
def extract_href():
    href_pool = []
    
    temp_link = link.split('//')[1]
    if 'www' in temp_link:
        link_internal = temp_link.split('www.')[1].split('/')[0]
    else: 
        link_internal = temp_link.split('/')[0]

    for href_list in href_lists:
        href = href_list['href'].strip()
        skip_href = False
        
        if len(href) > 1 and '@' not in href:
            for href_stop_string in href_stop_strings:                              # Eliminate all stop strings
                if re.search(href_stop_string.lower(), href.lower()):
                    skip_href = True
                    break     

            if skip_href == False: 
                if ((re.search(link_internal, href.lower())) or 
                    ('//' not in href and (href.startswith('/') or href.startswith('#')))):  

                    href_updated = urljoin(link, href)
                    href_pool.append(href_updated)
                      
    href_pool_clean = []
    [href_pool_clean.append(href) for href in href_pool if href not in href_pool_clean]
    
    return (href_pool_clean)

# %%
out = []
out_err = []
i = 1

for input in input_list:
    
    comp_name = input[0].strip()    # Capture company name
    link = input[1].strip()         # Capture company url
        
    try: 
        # Extract text from home page
        browser, page_soup = extract_text(link) 
        browser.quit()                                                          # Quit the browser for every URL 
        
        href_lists = page_soup.find_all(href = re.compile('\S'))
        href_pool_clean = extract_href()
        
        # Extract text from all href tags collected from home page
        for href_link in href_pool_clean:          
            try: 
                browser, page_soup = extract_text(href_link)

            except Exception as e:                                              # Write error record for run time errors
                print('url# {}: {} Error: {}'.format(i, href_link, e))
                write_error_file(href_link)

            finally: 
                browser.quit()                                                  # Quit the browser for every URL  
    
    except Exception as e:                                                      # Write error record for run time errors
        print('url# {}: {} Error: {}'.format(i, link, e))
        write_error_file(link)
    
    finally: 
        i = i + 1                                                               # Counter tracking # of records processed 
        if i % 10 == 0:                                                         # Print after every 10 records
            print('# of URLs processed:', i)
# Out:
# url# 6: https://www.mediquant.com/wp-content/themes/Divi/core/admin/fonts/modules.ttf Error: Message: TimedPromise timed out after 300000 ms
#
# # of URLs processed: 10
# url# 11: https://www.medhost.com/who-we-serve/ Error: Message: Reached error page: about:neterror?e=redirectLoop&u=https%3A//www.medhost.com/who-we-serve/&c=UTF-8&d=Firefox%20has%20detected%20that%20the%20server%20is%20redirecting%20the%20request%20for%20this%20address%20in%20a%20way%20that%20will%20never%20complete.
#
# url# 13: https://liberation.medecision.com/register/ Error: Message: Reached error page: about:neterror?e=dnsNotFound&u=https%3A//liberation.medecision.com/register/&c=UTF-8&d=We%20can%E2%80%99t%20connect%20to%20the%20server%20at%20liberation.medecision.com.
#
# url# 15: https://www.meddata.com/upcoming-conferences/?ical=1 Error: Message: TimedPromise timed out after 300000 ms
#
# # of URLs processed: 20
# url# 21: https://www.lumahealth.io/wp-content/themes/LumaHealth2/css/fonts/FreightSansProMedium-Regular.woff2 Error: Message: TimedPromise timed out after 300000 ms
#
# url# 26: https://www.lifepoint.com/wp-content/themes/Divi/core/admin/fonts/modules.ttf Error: Message: TimedPromise timed out after 300000 ms
#
# url# 29: mailto:?subject=Healthcare Solutions | LexisNexis Risk Solutions&body=Improve healthcare outcomes through consumer, provider and claims data analytics from LexisNexis Health Care. Learn more about our health care solutions. %0d%0a%0d%0ahttps://risk.lexisnexis.com/healthcare%0d%0a Error: Message: TimedPromise timed out after 300000 ms
#
# # of URLs processed: 30
# url# 33: https://www.kronos.com/kronos.xml Error: Message: TimedPromise timed out after 300000 ms
#
# url# 38: https://docs.intersystems.com/ Error: Message: Reached error page: about:neterror?e=netTimeout&u=https%3A//docs.intersystems.com/&c=UTF-8&d=The%20server%20at%20docs.intersystems.com%20is%20taking%20too%20long%20to%20respond.
#
# url# 38: https://wrc.intersystems.com/ Error: Message: Reached error page: about:neterror?e=netTimeout&u=https%3A//wrc.intersystems.com/&c=UTF-8&d=The%20server%20at%20wrc.intersystems.com%20is%20taking%20too%20long%20to%20respond.
#
# # of URLs processed: 40
# url# 48: https://www.infolinx.com/healthcare/ Error: Message: Reached error page: about:neterror?e=nssFailure2&u=https%3A//www.infolinx.com/healthcare/&c=UTF-8&d=%20
#
# # of URLs processed: 50
# url# 50: https://www.infinx.com/wp-content/themes/Avada/includes/lib/assets/fonts/icomoon/icomoon.woff Error: Message: TimedPromise timed out after 300000 ms
#
# url# 56: https://www.hyland.com/-/media/Themes/Hyland/Common/Common/fonts/gotham/GothamHTF-Light-woff2.woff2 Error: Message: TimedPromise timed out after 300000 ms
#
# url# 56: https://www.hyland.com/-/media/Themes/Hyland/Common/Common/fonts/gotham/GothamHTF-Light-woff.woff Error: Message: TimedPromise timed out after 300000 ms
#
# url# 56: https://www.hyland.com/-/media/Themes/Hyland/Common/Common/fonts/gotham/GothamHTF-LightItalic-woff2.woff2 Error: Message: TimedPromise timed out after 300000 ms
#
# url# 56: https://www.hyland.com/-/media/Themes/Hyland/Common/Common/fonts/gotham/GothamHTF-LightItalic-woff.woff Error: Message: TimedPromise timed out after 300000 ms
#
# url# 56: https://www.hyland.com/-/media/Themes/Hyland/Common/Common/fonts/gotham/GothamHTF-Book-woff2.woff2 Error: Message: TimedPromise timed out after 300000 ms
#
# url# 56: https://www.hyland.com/-/media/Themes/Hyland/Common/Common/fonts/gotham/GothamHTF-Book-woff.woff Error: Message: TimedPromise timed out after 300000 ms
#
# url# 56: https://www.hyland.com/-/media/Themes/Hyland/Common/Common/fonts/gotham/GothamHTF-BookItalic-woff2.woff2 Error: Message: TimedPromise timed out after 300000 ms
#
# url# 56: https://www.hyland.com/-/media/Themes/Hyland/Common/Common/fonts/gotham/GothamHTF-BookItalic-woff.woff Error: Message: TimedPromise timed out after 300000 ms
#
# url# 56: https://www.hyland.com/-/media/Themes/Hyland/Common/Common/fonts/gotham/GothamHTF-Medium-woff2.woff2 Error: Message: TimedPromise timed out after 300000 ms
#
# url# 56: https://www.hyland.com/-/media/Themes/Hyland/Common/Common/fonts/gotham/GothamHTF-Medium-woff.woff Error: Message: TimedPromise timed out after 300000 ms
#
# url# 56: https://www.hyland.com/-/media/Themes/Hyland/Common/Common/fonts/gotham/GothamHTF-MediumItalic-woff2.woff2 Error: Message: TimedPromise timed out after 300000 ms
#
# url# 56: https://www.hyland.com/-/media/Themes/Hyland/Common/Common/fonts/gotham/GothamHTF-MediumItalic-woff.woff Error: Message: TimedPromise timed out after 300000 ms
#
# url# 56: https://www.hyland.com/-/media/Themes/Hyland/Common/Common/fonts/gotham/GothamHTF-Bold-woff2.woff2 Error: Message: TimedPromise timed out after 300000 ms
#
# url# 56: https://www.hyland.com/-/media/Themes/Hyland/Common/Common/fonts/gotham/GothamHTF-Bold-woff.woff Error: Message: TimedPromise timed out after 300000 ms
#
# url# 56: https://www.hyland.com/-/media/Themes/Hyland/Common/Common/fonts/gotham/GothamHTF-BoldItalic-woff2.woff2 Error: Message: TimedPromise timed out after 300000 ms
#
# url# 56: https://www.hyland.com/-/media/Themes/Hyland/Common/Common/fonts/gotham/GothamHTF-BoldItalic-woff.woff Error: Message: TimedPromise timed out after 300000 ms
#
# url# 56: https://www.hyland.com/-/media/Themes/Hyland/Common/Common/images/favicons/hyland/site.webmanifest Error: Message: TimedPromise timed out after 300000 ms
#
# # of URLs processed: 60
# url# 61: http://hms.com/app/themes/wakefly/frontend/dist/fonts/ProximaNova/ProximaNova-Thin.otf Error: Message: TimedPromise timed out after 300000 ms
#
# url# 61: http://hms.com/app/themes/wakefly/frontend/dist/fonts/ProximaNova/ProximaNova-Extrabold.otf Error: Message: TimedPromise timed out after 300000 ms
#
# url# 61: http://hms.com/app/themes/wakefly/frontend/dist/fonts/ProximaNova/ProximaNova-Regular.otf Error: Message: TimedPromise timed out after 300000 ms
#
# url# 61: http://hms.com/app/themes/wakefly/frontend/dist/fonts/ProximaNova/ProximaNova-Bold.otf Error: Message: TimedPromise timed out after 300000 ms
#
# url# 61: http://hms.com/app/themes/wakefly/frontend/dist/fonts/la-solid-900.woff2 Error: Message: TimedPromise timed out after 300000 ms
#
# url# 63: https://www.healthwise.org/CMSPages/GetCSS.aspx?stylesheetname=dotOrg Error: Message: TimedPromise timed out after 300000 ms
#
# url# 63: https://www.healthwise.org/CMSPages/GetCSS.aspx?_webpartlayouts=166 Error: Message: TimedPromise timed out after 300000 ms
#
# url# 64: https://www.healthstream.com/ResourcePackages/HealthStream/assets/src/project/fonts/v-637564194260000000/GreycliffCF-Bold.woff Error: Message: TimedPromise timed out after 300000 ms
#
# url# 64: https://www.healthstream.com/ResourcePackages/HealthStream/assets/src/project/fonts/v-637564194260000000/AddingtonCFHealthStream-Light.woff Error: Message: TimedPromise timed out after 300000 ms
#
# url# 64: https://www.healthstream.com/ResourcePackages/HealthStream/assets/src/project/fonts/v-637564194260000000/GreycliffCF-DemiBold.woff Error: Message: TimedPromise timed out after 300000 ms
#
# url# 64: https://www.healthstream.com/ResourcePackages/HealthStream/assets/src/project/fonts/v-637564194280000000/GreycliffCF-Medium.woff Error: Message: TimedPromise timed out after 300000 ms
#
# url# 64: https://www.healthstream.com/ResourcePackages/HealthStream/assets/src/project/fonts/v-637564194280000000/GreycliffCF-Regular.woff Error: Message: TimedPromise timed out after 300000 ms
#
# url# 64: https://www.healthstream.com/ResourcePackages/HealthStream/assets/src/project/fonts/v-637564194280000000/fa-solid-900.woff2 Error: Message: TimedPromise timed out after 300000 ms
#
# # of URLs processed: 70
# url# 74: https://www.thehcigroup.com/hs-fs/hub/280490/file-204638468-ico/favicon.ico Error: Message: TimedPromise timed out after 300000 ms
#
# url# 75: https://hbisolutions.com/wp-content/themes/Divi/core/admin/fonts/modules.ttf Error: Message: TimedPromise timed out after 300000 ms
#
# url# 76: https://www.hayesmanagement.com/wp-content/themes/Divi/core/admin/fonts/modules.ttf Error: Message: TimedPromise timed out after 300000 ms
#
# url# 77: https://www.harrishealthcare.com/events/?ical=1 Error: Message: TimedPromise timed out after 300000 ms
#
# url# 78: https://www.harmonyhit.com/AttendediAgent-6.0.exe Error: Message: TimedPromise timed out after 300000 ms
# url# 78: https://www.harmonyhit.com/AttendediAgent_regfix.exe Error: Message: TimedPromise timed out after 300000 ms
#
# url# 78: https://www.harmonyhit.com/AttendediAgent-5.4.exe Error: Message: TimedPromise timed out after 300000 ms
#
# url# 78: https://www.harmonyhit.com/UnattendediAgent-6.0.exe Error: Message: TimedPromise timed out after 300000 ms
#
# url# 78: https://www.harmonyhit.com/UnattendediAgent-5.4.exe Error: Message: TimedPromise timed out after 300000 ms
#
# # of URLs processed: 80
# url# 82: https://cdn.goliathtechnologies.com/wp-content/themes/Divi/core/admin/fonts/modules.ttf Error: Message: TimedPromise timed out after 300000 ms
#
# url# 86: https://www.gehealthcare.com/dist/GEHC/Project/GEHC/fontStyles/inspira/GEInspiraSerif-BoldItalic-v01.woff2 Error: Message: TimedPromise timed out after 300000 ms
#
# url# 86: https://www.gehealthcare.com/dist/GEHC/Project/GEHC/fontStyles/inspira/GEInspiraSerif-Bold-v01.woff2 Error: Message: TimedPromise timed out after 300000 ms
#
# url# 86: https://www.gehealthcare.com/dist/GEHC/Project/GEHC/fontStyles/inspira/GEInspiraSans-Bold-v01.woff2 Error: Message: TimedPromise timed out after 300000 ms
#
# url# 86: https://www.gehealthcare.com/dist/GEHC/Project/GEHC/fontStyles/inspira/GEInspiraSans-Regular-v01.woff2 Error: Message: TimedPromise timed out after 300000 ms
#
# url# 86: https://www.gehealthcare.com/dist/GEHC/Project/GEHC/fontStyles/inspira/GEInspiraSans-Italic-v01.woff2 Error: Message: TimedPromise timed out after 300000 ms
#
# url# 86: mailto:?subject=Social Share Widget Left&body=Visit to read more: https://www.gehealthcare.com/ Error: Message: TimedPromise timed out after 300000 ms
#
# url# 87: https://www.galenhealthcare.com/events/?ical=1 Error: Message: TimedPromise timed out after 300000 ms
#
# url# 88: https://www.forwardhealthgroup.com/ Error: Message: Reached error page: about:neterror?e=netTimeout&u=https%3A//www.forwardhealthgroup.com/&c=UTF-8&d=The%20server%20at%20www.forwardhealthgroup.com%20is%20taking%20too%20long%20to%20respond.
#
# # of URLs processed: 90
# url# 91: http://www.formativhealth.com/wp-content/themes/Divi/core/admin/fonts/modules.ttf Error: Message: TimedPromise timed out after 300000 ms
#
# # of URLs processed: 100
# url# 104: https://www.endosoft.com/endosoft_documents/endovault-ehr-3/endovault_ehr_cost_limitations_onc_2015.xlsx Error: Message: TimedPromise timed out after 300000 ms
#
# url# 105: https://www.emids.com/events/?ical=1 Error: Message: TimedPromise timed out after 300000 ms
#
# url# 108: http://jobs.ellkay.com Error: Message: Reached error page: about:neterror?e=netTimeout&u=http%3A//jobs.ellkay.com/&c=UTF-8&d=The%20server%20at%20jobs.ellkay.com%20is%20taking%20too%20long%20to%20respond.
#
# # of URLs processed: 110
# url# 110: https://ehealthexchange.org/all-events/?ical=1 Error: Message: TimedPromise timed out after 300000 ms
#
# url# 118: https://www.dssinc.com/homepage?format=rss Error: Message: TimedPromise timed out after 300000 ms
#
# # of URLs processed: 120
# url# 125: https://www.dssinc.com/homepage?format=rss Error: Message: TimedPromise timed out after 300000 ms

# %%
df_out = pd.DataFrame(out, columns = header)
df_out.drop_duplicates(subset = ['Company Name', 'Claim', 'Modifier', 'Evidence'], inplace = True)

#df_out.sort_values(by = ['Company Name', 'Claim', 'Modifier', 'Evidence'], inplace = True)
#df_out.reset_index(drop = True, inplace = True)

df_out.to_csv(out_file, index = False, encoding='utf-8')
df_out
# Out:
#                    Company Name       Claim Modifier  \
# 0           Meditology Services     process  leverag
# 1           Meditology Services        data  leverag
# 2           Meditology Services        data   better
# 3                      MEDITECH     outcome   improv
# 8                      MEDITECH  efficiency   improv
# ...                         ...         ...      ...
# 25829  Document Storage Systems     outcome   improv
# 25830  Document Storage Systems        time    lower
# 25831  Document Storage Systems        data   improv
# 25832  Document Storage Systems        data    lower
# 25833  Document Storage Systems     outcome   improv
#
#                                                 Evidence  \
# 0      As a provider of data analytics to health plan...
# 1      As a provider of data analytics to health plan...
# 2      UVM had better security protocols than many ho...
# 3      Our customers are improving outcomes with real...
# 8      Princeton Community Hospital Improves Response...
# ...                                                  ...
# 25829  TheraDoc provides a real-time picture of the r...
# 25830  TheraDoc provides a real-time picture of the r...
# 25831  TheraDoc provides a real-time picture of the r...
# 25832  TheraDoc provides a real-time picture of the r...
# 25833                Improve patient outcomes and safety
#
#                                                     Link
# 0      https://www.meditologyservices.com/incident-re...
# 1      https://www.meditologyservices.com/incident-re...
# 2      https://www.meditologyservices.com/how-hackers...
# 3                              https://ehr.meditech.com/
# 8                 https://ehr.meditech.com/ehr-solutions
# ...                                                  ...
# 25829               https://www.dssinc.com/theradoc-form
# 25830               https://www.dssinc.com/theradoc-form
# 25831               https://www.dssinc.com/theradoc-form
# 25832               https://www.dssinc.com/theradoc-form
# 25833               https://www.dssinc.com/theradoc-form
#
# [9899 rows x 5 columns]

# %%
df_out_err = pd.DataFrame(out_err, columns = header_err)
df_out_err.drop_duplicates(inplace = True)

df_out_err.to_csv(out_file_err, index = False, encoding='utf-8')
df_out_err
# Out:
#                 Company Name  \
# 0                  MediQuant
# 1                    MEDHOST
# 2                 Medecision
# 3                    MedData
# 4                Luma Health
# ..                       ...
# 62        eMids Technologies
# 63                    Ellkay
# 64          eHealth Exchange
# 65                 DSS, Inc.
# 66  Document Storage Systems
#
#                                                  Link  \
# 0   https://www.mediquant.com/wp-content/themes/Di...
# 1               https://www.medhost.com/who-we-serve/
# 2         https://liberation.medecision.com/register/
# 3   https://www.meddata.com/upcoming-conferences/?...
# 4   https://www.lumahealth.io/wp-content/themes/Lu...
# ..                                                ...
# 62               https://www.emids.com/events/?ical=1
# 63                             http://jobs.ellkay.com
# 64     https://ehealthexchange.org/all-events/?ical=1
# 65         https://www.dssinc.com/homepage?format=rss
# 66         https://www.dssinc.com/homepage?format=rss
#
#                                                 Error
# 0   Message: TimedPromise timed out after 300000 ms\n
# 1   Message: Reached error page: about:neterror?e=...
# 2   Message: Reached error page: about:neterror?e=...
# 3   Message: TimedPromise timed out after 300000 ms\n
# 4   Message: TimedPromise timed out after 300000 ms\n
# ..                                                ...
# 62  Message: TimedPromise timed out after 300000 ms\n
# 63  Message: Reached error page: about:neterror?e=...
# 64  Message: TimedPromise timed out after 300000 ms\n
# 65  Message: TimedPromise timed out after 300000 ms\n
# 66  Message: TimedPromise timed out after 300000 ms\n
#
# [67 rows x 3 columns]

# %%
end = datetime.now().strftime('%H:%M:%S')
end_time = time.time()
seconds = end_time - start_time

print('Program Start Time   :', start)
print('Program End Time     :', end)
print('Program Elapsed Time :', time.strftime('%H:%M:%S', time.gmtime(seconds)))
# Out:
# Program Start Time   : 04:42:39
# Program End Time     : 05:12:48
# Program Elapsed Time : 00:30:08
