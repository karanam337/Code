# %% [markdown]
# This tutorial is taken from the following source: https://realpython.com/twitter-bot-python-tweepy/

# %%
import tweepy

# %%
# Authenticate to Twitter
auth = tweepy.OAuthHandler("jRAZn7C9pnVuLLqgfm2gqIbkJ", "HoS3nHFOgHPkRdl5sPDKNNhwA1szMfNFjL7o7vhl9BcG4hr2Zh")
auth.set_access_token("1417985756-Vy43RbsCcbem79hEaoXq1Og8wbyAgnX9Rtu6bub", \
                      "SUxcazgVjkMOfEp2fUQGfTwdtBKryyr2wUdwlWvZ5TgGg")

# Create API object
api = tweepy.API(auth)

# Create a tweet
api.update_status("Back again after a long time....nothing much going on.")
# Out:
# Status(_api=<tweepy.api.API object at 0x108e02f98>, _json={'created_at': 'Sun Oct 06 21:40:00 +0000 2019', 'id': 1180960924401885184, 'id_str': '1180960924401885184', 'text': 'Back again after a long time....nothing much going on.', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': []}, 'source': '<a href="https://www.uta.edu" rel="nofollow">Testing for Orange</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 1417985756, 'id_str': '1417985756', 'name': 'Sridhar Nerur', 'screen_name': 'jeeves59', 'location': '', 'description': '', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 18, 'friends_count': 15, 'listed_count': 0, 'created_at': 'Fri May 10 12:26:24 +0000 2013', 'favourites_count': 5, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': Fals
# ...

# %%
#creating a new api object with warning to be displayed when rate is exceeded
# Create API object
api = tweepy.API(auth, wait_on_rate_limit=True,
    wait_on_rate_limit_notify=True)

# %%
user = api.get_user("Jeeves59")

print("User details:")
print(user.name)
print(user.description)
print(user.location)

print("Followers:")
for follower in user.followers():
    print(follower.name)
# Out:
# User details:
# Sridhar Nerur
#
#
# Followers:
# Abhishek
# Mayur P. Joshi
# B S G Srinivasa Rao
# UTA College of Business
# Ruchit
# riveto
# Kuttimani Tamilmani
# Ganesh Vaidyanathan
# Thought Shastra
# bharat parikh
# Porochista Academy
# Reza Sardari
# Hariharaniyeer
# MounaSomaiah
# Pavan Kumar
# Rohan
# Ada poda!
# sid vyawahare

# %%
#10 recent English tweets that contain the word Python
for tweet in api.search(q="Python", lang="en", rpp=10):
    print(f"{tweet.user.name}:{tweet.text}")
# Out:
# The Devel Bot:RT @harunaadoga: Day 7 of #100DaysOfCode with #Python.
# Played with the BeautifulSoup library for web scraping. https://t.co/rgBIzEPx5x http…
# 🤖 #100DAYSOFCODE:RT @hadjer_11: Day 3-4 #100DaysOfCode
#
# Get a quick refresh on regex and complete the 4 PRs (and more) requested for #Hacktoberfest
#
# #pyth…
# CodersNotes:RT @hadjer_11: Day 3-4 #100DaysOfCode
#
# Get a quick refresh on regex and complete the 4 PRs (and more) requested for #Hacktoberfest
#
# #pyth…
# Vineeth Menon:@javinpaul 1. First language: C++
# 2. Had difficulties: JavaScript
# 3. Most used: Java and Node.js
# 4. Totally hate: P… https://t.co/5gnpCxu4L0
# Graham Dumpleton:So off to Python to hack up a solution, which is where filecmp module comes in.
# Katherine Michel @ PyGotham:RT @teach_python: @glasnt @ThePSF Follow me for updates and pm if you're interested in contributing! #CSEd #PyEdu #Python
# hadjer:Day 3-4 #100DaysOfCode
#
# ...

# %%
#What is trending worldwide?
trends_result = api.trends_place(1)
for trend in trends_result[0]["trends"]:
    print(trend["name"])

#you can get all locations using api.trends_available()

# %%
number_of_tweets=200
tweets = api.user_timeline(screen_name="realDonaldTrump")

# %%
for tweet in tweets:
    print(tweet.text)
# Out:
# Sleepy Eyes Chuck Todd of “Meet the Press” had a total meltdown in his interview with highly reaspected Senator… https://t.co/j0usm2hmAn
# Join me at the Target Center in Minneapolis, Minnesota this Thursday, October 10th at 7:00pm! Tickets:… https://t.co/Y0JKKtFtsk
# Good job, I must say, by Bob Woodward on “Deface the Nation.” The CBS no name host(ess), and other guest, Peter Bak… https://t.co/bn0vwftqbI
# RT @senjudiciary: TODAY: Chairman @LindseyGrahamSC urges Prime Ministers of Australia, Italy and the United Kingdom to continue working wit…
# RT @LindseyGrahamSC: Who were these people?
#
# What were they up to?
#
# Only by full disclosure can President @realDonaldTrump adequately…
# RT @LindseyGrahamSC: Also, House Republicans should have the ability to find out ALL THOSE involved in providing information to the whistle…
# RT @LindseyGrahamSC: It’s not right Democrats in the House helped the whistleblower prepare their complaint.
#
# https://t.co/LpE7y2bVFb
# ...

# %%
search_words = "#ericsson"
date_since = "2019-01-01"

# %%
tweets = tweepy.Cursor(api.search,
              q=search_words,
              lang="en",
              since=date_since).items(100)
for tweet in tweets:
    print(tweet.text)
# Out:
# RT @EricssonMEA: Have you been keeping track of our @Etisalat and #Ericsson #Experience5G Bus 🚎? Here's a sneak peek into what you can expe…
# RT @EricssonMEA: Have you been keeping track of our @Etisalat and #Ericsson #Experience5G Bus 🚎? Here's a sneak peek into what you can expe…
# RT @EricssonMEA: Even if you're not at #GITEX2019, we've got you covered with daily #EricssonLive sessions straight from the #Ericsson stan…
# RT @EricssonMEA: Have you been keeping track of our @Etisalat and #Ericsson #Experience5G Bus 🚎? Here's a sneak peek into what you can expe…
# RT @EricssonMEA: Have you been keeping track of our @Etisalat and #Ericsson #Experience5G Bus 🚎? Here's a sneak peek into what you can expe…
# RT @EricssonMEA: Have you been keeping track of our @Etisalat and #Ericsson #Experience5G Bus 🚎? Here's a sneak peek into what you can expe…
# ...

# %%
new_search = "climate+change -filter:retweets"

tweets = tweepy.Cursor(api.search,
                   q=new_search,
                   lang="en",
                   since='2018-04-23').items(1000)

all_tweets = [tweet.text for tweet in tweets]
all_tweets[:5]
# Out:
# ['@LukeGromen "climate change" (conveniently ignoring temperatures pre-1960)\n\nImagine being the people who have such… https://t.co/zl90AW7WD8',
#  '@3ku1 @MariaSherwood2 Perhaps @simonjbridges AKA #beijingbridges, slept through the recent climate change protest.… https://t.co/CMq8DqJWIU',
#  '@CrPaulBishop Agree we need to have better ways to communicate the concerns people have in relation to climate change.',
#  'GOOD MORNING to people who believe in climate change only',
#  '@DavidBCollum Who owns those media outlets? You can’t approach climate change in an objective and rational way with… https://t.co/LPSCIP6OZs']
