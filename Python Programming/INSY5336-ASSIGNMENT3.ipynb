# %% [markdown]
# ## HOMEWORK ASSIGNMENT 3 SPRING 2020
# ## INSY 5336 001 PYTHON PROGRAMMING
# ### KAJAL JAIN ID-1001815317

# %% [markdown]
# ## PROGRAM 1:
# ## ALGORITHM FOLLOWED:
#
# #### 1) Import random module from library and create function named string with argument value 'a'
# #### 2) Create the empty word to store the scrambled word
# #### 3) Using randint fucntion to generate  random number between (0-len(a)-1)
# #### 4) In main block, creating empty dictionary, 'Wnewdict' and variable list named 'Wlist' to put as a list
# #### 5) Prompt user to input name of file, use try and except block to handle error and exceptions
# #### 6) Print "Oops!File not found or could not be opened,Please enter correct name of file which exist." if file does not exist
# #### 7) Open file using fhandle
# #### 8) Using for loop to scan entire file and strip white spaces throught the file using strip(), use key,a=line.split(':') to seperate words and meaning
# #### 9) Prompt user to input '?' for hint or meaning of unscrambled word
# #### 10) If unscarmbled word is correct, ask user, if they wants to continue or no, buy entering yes/no
# #### 11) if yes, repeat steps else, exit and print"goodbye" and come out of the loop
# #### 12) End of program
#
# ## Note: In the program below, I am using file, " mywords-1.txt" where, words and , meanings are seperated by " : ".(For reference purpose, I will upload the file I used for running the program)

# %%
import random                                                             #import random module
def string(a):                                                            #function definition   
    word = ''                                                             #create the empty variable to store the scramble word
    for i in range(len(a)):              #for loop to scramble the words conditions in range of (length-1)  
        array = random.randint(0, len(a)-1) #use randint function to generate random numbers from 0 to 1 less than len(a) 
        word = word+a[array]               #adding each index value to word
        a =a[:array] + a[array+1:]      
    return word                             #return value fo word                  

Wnewdict={}                 #creating new empty dictionary                 
filename=input("Please input name of 'words and their meaning' file:")  #prompt user to input the filename
try:                                                             #try block to handle exception                               
    fhandle=open(filename)                                    #open entered file 
except:                                                       #except block to handle the errors                           
    print("Oops!File not found or could not be opened,Please enter correct name of file which exist.")  #print if the file not found
else:
    for line in fhandle:                                      #for each line in file
        line=line.strip()                                 #to strip the end and beginning spaces of the line in file
        key,a=line.split(',')                   #separating the meaning with the word of entered file
        Wnewdict[key]=a
    Wlist=list(Wnewdict)                     #variable Wlist to put as a list from dictionary
    randomA=random.choice(Wlist)            #randomly select an item from a Wlist
    stringA=string(randomA)                 #call function                 
    print("Unscramble the following letters to form a word. Type “?” for the meaning of the unscrambled word:",stringA) #display the unscramble  word and print to ask the user ? mark to enter 
    while True:                 #while condition is true
        x=input()
        x = x.lower()       #to convert the input to lower case and handle the case sensitive words
        if x.strip()=='?':  #if the input entered is "?" display the meaning of scrambled word 
            print('The word means:',Wnewdict[randomA])  #display the meaning of the scrambled word 
        elif x.strip()!=randomA.strip():                                      
            print("Entered answer is wrong, please try again[or enter ? for hint]: ")   #print if the entered input is wrong and ask user to try again
        else:
            Fresult=input("You got it! Do you want to continue [yes or no]:")  #print if the word entered is correct and ask user if he/she wnats to continue further or not
            while not(Fresult == "yes" or Fresult == "no"): #ask user yes or no to continue
                print("Please enter yes to continue, or, no to quit:") #print yes or no to proceed
                Fresult=input("You got it!Do you want to continue:") #print if the scranmbled word identified is correct and ask to continue
            if (Fresult == "yes"):
                randomA=random.choice(Wlist)#to randomly select an item from a Wlist
                stringA=string(randomA)
                print("Unscramble the following letters to form a word. Type “?” for the meaning of the unscrambled word:",stringA)
                x=input()
                print('The word means:',Wnewdict[randomA])  #print the meaning of the scrambled word
            else:
                print("Goodbye!")       #else print goodbye
                break       # come out of the loop
# Out:
# Please input name of 'words and their meaning' file:mywords.txt
# Unscramble the following letters to form a word. Type “?” for the meaning of the unscrambled word: onuepelc
# ?
# The word means: great wealth
# opluence
# Entered answer is wrong, please try again[or enter ? for hint]:

# %% [markdown]
# ## PROGRAM 2
# ## ALGORITHM FOLLOWED:
#
# #### 1) Import sqrt module from math lib and create func cal(), to calculate the difference between corresponding reviews and the sums of the squares of the terms and the square root of the sum of differences which is the euclidean score and return the value result at the end of the function definition and rounding off to 2 with three argument values
# #### 2) Create another function definition called 'func1()' and func2() in the same cell to input the reviewer1 and reviewer2 conditions and compare the two reviewers reviews.
# #### 3)  Evaluate the euclidean distance value based on the similarity between the reviewer's reviews
# #### 4) Start the main program , where we call the defined functions
# #### 5) Create the dictionary and the nested dictionary dict_1 and dict_2
# #### 6) Ask the user to input the file name and use try and except block to handle the exception like if the file doesnt exist
# #### 7) Use the for loop to check the file and scan through and strip the values in file based on space using strip() and separate the key and values based on comma, and stores the keys as list and stores the values as list
# #### 8) Use while loop condition true to compute the similarity between two reviewers provided by the user and to compute the similarity between one user provided reviewer and all other reviewers in the database
# #### 9) Call the function fync1() or func2() in the function main depending on the conditions.
# #### 10) Else come out of loop and print "Goodbye"
# #### 11) End of program
#
#
# ## NOTE: In the program below, I created three function blocks, 1) func cal() 2) func1() 3) func2() and used file "movie_reviews.txt" to run the program.

# %%
from math import sqrt                                #import sqrt function module from math library                               
def cal(x, x1, x2):                                  #define function with the arguments x,x1,x2  
    a = {}                                           #create empty dictionary                                      
    for i in x[x1]:                                  #use for loop to check conditions
        if i in x[x2]:                               #if satisfy
            a[i] = 1                                 #put 1 in a[i] of the result of for loop 
    if len(a) == 0:                                  #if length of the dictionary is 0,return 0
        return 0                                     #return 0
    sum_sqrs = sum([pow(x[x1][i] - x[x2][i], 2) for i in a]) #calculate the sum of the squares
    result = round(sqrt(sum_sqrs),2)                 #save the euclidean distance in a variable named 'result'
    return result                                    #return the value of result

def func1():                                              # create function fucn1()
    R1 = input('Please input name of first reviewer: ')    #enter reviewer name1
    R1 = R1.lower()                                       #convert into lower case
    R2 = input('Please input name of second reviewer: ')   #enter reviewer name2 
    R2 = R2.lower()
    if R1==R2:                                            #compare the two reviewers names
        print('Sorry! Names cannot be same, please try again')  #print if the entered names are same and ask to try again
    else:
        Euclidean_dis = cal(dict_1, R1, R2)                #call function to calculate the euclidean distance
        print('The similarity between ', R1, 'and ', R2, 'is ', Euclidean_dis) #display result
        
def func2():                                     #Function defined for the comparison of one reviewer with all others
    Name = input('Please input name of reviewer: ')  #enter reviewer name
    Name = Name.lower()                                  
    print('The Similarity Scores are: ')            #print the the similarity scores between all reviewers
    for k1 in dict_1:                               #use the for loop to store the values k1 in dictionary dict_1
        distance = cal(dict_1,Name, k1)               #compute the euclidean distance and store in distance variable
        if distance != 0:                             
            print('Similarity to ', k1,':', distance)  #display result

dict_1 = {}                                     #create the dictionary dict_1 
dict_2 = {}                                     #create dict_2 created to define parts of dict_1

try:                                            #try block to handle error and exception
    
    file = open(input('Enter the name of the movie reviews file: '))  #Input file name

except:

    print(' Entered file does not exist or, the file is corrupt')    #display if entered file is not found
else:
    for line in file:                           #for each line in file
        line = line.strip('')                   #strip spaces
        key = line.split(',', 1)[0]             #separate the key and values based on " , "
        key = key.lower()                         #lower case conversion
        st_val = line.split(',')[1:]            # st_val variable stores the string values as a list
        dict_2_key = list()                     #store the keys as list
        dict_2_value = list()                   #store the values as list
        for i in range(len(st_val)):            #for loop to check the key value on the basis of length of string values
            if i % 2 == 0:                      #if the condition satisfies 
                dict_2_key.append(st_val[i])    #to store the values in variable, i th position in key list
            else:
                dict_2_value.append(float(st_val[i])) #store in value variable list
        dict_2 = dict(zip(dict_2_key, dict_2_value))  #to store as a dictionary in dict_2 variable
        dict_1[key] = dict_2                          #dict_1[key] has the value of dict_2 i.e nested dictionary
    try:
        while True:                                   #while True
            output = int(input("What do you want to do? Please enter 1 for similarity between two reviewers,\n"
                  "or Enter 2 for similarity between one reviewer and all others in the file or Enter 3 to exit: "))#ask input to enter 1 ,2 or 3 
            if output == 1:                           
                func1()                                #func1() if input is 1
            elif output == 2:                             
                func2()                                #func2() if input is 2
            else:                                      #else print goodbye
                print('Goodbye!')
                break                                 #break to come out of the loop
    except:                                           #except to handle error
        print('Oops! name entered is not found. Please enter correct names and try again') #print if the name is not found in the file

# %%
text = 'gregarious,fond of company; sociable'
key,a=text.split(',')
print(key)
print(a)
# Out:
# gregarious
# fond of company; sociable
